# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !nvidia-smi
# Out:
# Tue Apr  9 11:59:52 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P0              27W /  70W |   3091MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
# !pip install datasets accelerate colossalai locust
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.18.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.29.1)
# Requirement already satisfied: colossalai in /usr/local/lib/python3.10/dist-packages (0.3.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2024.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.2)
# Requirement already satisfied: pre-commit in /usr/local/lib/python3.10/dist-packages (from colossalai) (3.7.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from colossalai) (13.7.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from colossalai) (8.1.7)
# Requirement already satisfied: fabric in /usr/local/lib/python3.10/dist-packages (from colossalai) (3.2.2)
# Requirement already satisfied: contexttimer in /usr/local/lib/python3.10/dist-packages (from colossalai) (0.3.3)
# Requirement already satisfied: ninja in /usr/local/lib/python3.10/dist-packages (from colossalai) (1.11.1.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from colossalai) (0.7.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from colossalai) (2.6.4)
# Requirement already satisfied: ray in /usr/local/lib/python3.10/dist-packages (from colossalai) (2.10.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from colossalai) (0.1.99)
# Requirement already satisfied: google in /usr/local/lib/python3.10/dist-packages (from colossalai) (2.0.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from colossalai) (3.20.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate) (12.4.127)
# Requirement already satisfied: invoke>=2.0 in /usr/local/lib/python3.10/dist-packages (from fabric->colossalai) (2.2.0)
# Requirement already satisfied: paramiko>=2.4 in /usr/local/lib/python3.10/dist-packages (from fabric->colossalai) (3.4.0)
# Requirement already satisfied: decorator>=5 in /usr/local/lib/python3.10/dist-packages (from fabric->colossalai) (5.1.1)
# Requirement already satisfied: deprecated>=1.2 in /usr/local/lib/python3.10/dist-packages (from fabric->colossalai) (1.2.14)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from google->colossalai) (4.12.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pre-commit->colossalai) (3.4.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pre-commit->colossalai) (2.5.35)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from pre-commit->colossalai) (1.8.0)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.10/dist-packages (from pre-commit->colossalai) (20.25.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->colossalai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /usr/local/lib/python3.10/dist-packages (from pydantic->colossalai) (2.16.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray->colossalai) (4.19.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray->colossalai) (1.0.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->colossalai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->colossalai) (2.16.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated>=1.2->fabric->colossalai) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->colossalai) (0.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nodeenv>=0.11.1->pre-commit->colossalai) (67.7.2)
# Requirement already satisfied: bcrypt>=3.2 in /usr/local/lib/python3.10/dist-packages (from paramiko>=2.4->fabric->colossalai) (4.1.2)
# Requirement already satisfied: cryptography>=3.3 in /usr/local/lib/python3.10/dist-packages (from paramiko>=2.4->fabric->colossalai) (42.0.5)
# Requirement already satisfied: pynacl>=1.5 in /usr/local/lib/python3.10/dist-packages (from paramiko>=2.4->fabric->colossalai) (1.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from virtualenv>=20.10.0->pre-commit->colossalai) (0.3.8)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.10/dist-packages (from virtualenv>=20.10.0->pre-commit->colossalai) (4.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->google->colossalai) (2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray->colossalai) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray->colossalai) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray->colossalai) (0.18.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=3.3->paramiko>=2.4->fabric->colossalai) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=3.3->paramiko>=2.4->fabric->colossalai) (2.22)

# %%
# !pip freeze
# Out:
# absl-py==1.4.0
# accelerate==0.29.1
# aiohttp==3.9.3
# aiosignal==1.3.1
# alabaster==0.7.16
# albumentations==1.3.1
# altair==4.2.2
# annotated-types==0.6.0
# anyio==3.7.1
# appdirs==1.4.4
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# array_record==0.5.1
# arviz==0.15.1
# astropy==5.3.4
# astunparse==1.6.3
# async-timeout==4.0.3
# atpublic==4.1.0
# attrs==23.2.0
# audioread==3.0.1
# autograd==1.6.2
# Babel==2.14.0
# backcall==0.2.0
# bcrypt==4.1.2
# beautifulsoup4==4.12.3
# bidict==0.23.1
# bigframes==1.0.0
# bleach==6.1.0
# blinker==1.4
# blis==0.7.11
# blosc2==2.0.0
# bokeh==3.3.4
# bqplot==0.12.43
# branca==0.7.1
# build==1.2.1
# CacheControl==0.14.0
# cachetools==5.3.3
# catalogue==2.0.10
# certifi==2024.2.2
# cffi==1.16.0
# cfgv==3.4.0
# chardet==5.2.0
# charset-normalizer==3.3.2
# chex==0.1.86
# click==8.1.7
# click-plugins==1.1.1
# cligj==0.7.2
# cloudpathlib==0.16.0
# cloudpickle==2.2.1
# cmake==3.27.9
# cmdstanpy==1.2.2
# colorcet==3.1.0
# colorlover==0.3.0
# colossalai==0.3.6
# colour==0.1.5
# community==1.0.0b1
# confection==0.1.4
# cons==0.4.6
# contextlib2==21.6.0
# contexttimer==0.3.3
# contourpy==1.2.1
# cryptography==42.0.5
# cufflinks==0.17.3
# cupy-cuda12x==12.2.0
# cvxopt==1.3.2
# cvxpy==1.3.3
# cycler==0.12.1
# cymem==2.0.8
# Cython==3.0.10
# dask==2023.8.1
# datascience==0.17.6
# datasets==2.18.0
# db-dtypes==1.2.0
# dbus-python==1.2.18
# debugpy==1.6.6
# decorator==5.1.1
# defusedxml==0.7.1
# Deprecated==1.2.14
# dill==0.3.8
# distlib==0.3.8
# distributed==2023.8.1
# distro==1.7.0
# dlib==19.24.4
# dm-tree==0.1.8
# docstring_parser==0.16
# docutils==0.18.1
# dopamine-rl==4.0.6
# duckdb==0.9.2
# earthengine-api==0.1.397
# easydict==1.13
# ecos==2.0.13
# editdistance==0.6.2
# eerepr==0.0.4
# einops==0.7.0
# en-core-web-sm @ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl#sha256=86cc141f63942d4b2c5fcee06630fd6f904788d2f0ab005cce45aadb8fb73889
# entrypoints==0.4
# et-xmlfile==1.1.0
# etils==1.7.0
# etuples==0.3.9
# exceptiongroup==1.2.0
# fabric==3.2.2
# fastai==2.7.14
# fastcore==1.5.29
# fastdownload==0.0.7
# fastjsonschema==2.19.1
# fastprogress==1.0.3
# fastrlock==0.8.2
# filelock==3.13.3
# fiona==1.9.6
# firebase-admin==5.3.0
# Flask==2.2.5
# flatbuffers==24.3.25
# flax==0.8.2
# folium==0.14.0
# fonttools==4.50.0
# frozendict==2.4.1
# frozenlist==1.4.1
# fsspec==2023.6.0
# future==0.18.3
# gast==0.5.4
# gcsfs==2023.6.0
# GDAL==3.6.4
# gdown==4.7.3
# geemap==0.32.0
# gensim==4.3.2
# geocoder==1.38.1
# geographiclib==2.0
# geopandas==0.13.2
# geopy==2.3.0
# gin-config==0.5.0
# glob2==0.7
# google==2.0.3
# google-ai-generativelanguage==0.4.0
# google-api-core==2.11.1
# google-api-python-client==2.84.0
# google-auth==2.27.0
# google-auth-httplib2==0.1.1
# google-auth-oauthlib==1.2.0
# google-cloud-aiplatform==1.46.0
# google-cloud-bigquery==3.12.0
# google-cloud-bigquery-connection==1.12.1
# google-cloud-bigquery-storage==2.24.0
# google-cloud-core==2.3.3
# google-cloud-datastore==2.15.2
# google-cloud-firestore==2.11.1
# google-cloud-functions==1.13.3
# google-cloud-iam==2.14.3
# google-cloud-language==2.13.3
# google-cloud-resource-manager==1.12.3
# google-cloud-storage==2.8.0
# google-cloud-translate==3.11.3
# google-colab @ file:///colabtools/dist/google-colab-1.0.0.tar.gz#sha256=0834445814613cace47f422e23da1f3f34ba9fa8725a67e4cf65ae6823480b0d
# google-crc32c==1.5.0
# google-generativeai==0.3.2
# google-pasta==0.2.0
# google-resumable-media==2.7.0
# googleapis-common-protos==1.63.0
# googledrivedownloader==0.4
# graphviz==0.20.3
# greenlet==3.0.3
# grpc-google-iam-v1==0.13.0
# grpcio==1.62.1
# grpcio-status==1.48.2
# gspread==3.4.2
# gspread-dataframe==3.3.1
# gym==0.25.2
# gym-notices==0.0.8
# h5netcdf==1.3.0
# h5py==3.9.0
# holidays==0.46
# holoviews==1.17.1
# html5lib==1.1
# httpimport==1.3.1
# httplib2==0.22.0
# huggingface-hub==0.20.3
# humanize==4.7.0
# hyperopt==0.2.7
# ibis-framework==8.0.0
# identify==2.5.35
# idna==3.6
# imageio==2.31.6
# imageio-ffmpeg==0.4.9
# imagesize==1.4.1
# imbalanced-learn==0.10.1
# imgaug==0.4.0
# importlib_metadata==7.1.0
# importlib_resources==6.4.0
# imutils==0.5.4
# inflect==7.0.0
# iniconfig==2.0.0
# intel-openmp==2023.2.4
# invoke==2.2.0
# ipyevents==2.0.2
# ipyfilechooser==0.6.0
# ipykernel==5.5.6
# ipyleaflet==0.18.2
# ipython==7.34.0
# ipython-genutils==0.2.0
# ipython-sql==0.5.0
# ipytree==0.2.2
# ipywidgets==7.7.1
# itsdangerous==2.1.2
# jax==0.4.26
# jaxlib @ https://storage.googleapis.com/jax-releases/cuda12/jaxlib-0.4.26+cuda12.cudnn89-cp310-cp310-manylinux2014_x86_64.whl#sha256=813cf1fe3e7ca4dbf5327d6e7b4fc8521e92d8bba073ee645ae0d5d036a25750
# jeepney==0.7.1
# jieba==0.42.1
# Jinja2==3.1.3
# joblib==1.3.2
# jsonpickle==3.0.3
# jsonschema==4.19.2
# jsonschema-specifications==2023.12.1
# jupyter-client==6.1.12
# jupyter-console==6.1.0
# jupyter-server==1.24.0
# jupyter_core==5.7.2
# jupyterlab_pygments==0.3.0
# jupyterlab_widgets==3.0.10
# kaggle==1.5.16
# kagglehub==0.2.2
# keras==2.15.0
# keyring==23.5.0
# kiwisolver==1.4.5
# langcodes==3.3.0
# launchpadlib==1.10.16
# lazr.restfulclient==0.14.4
# lazr.uri==1.0.6
# lazy_loader==0.3
# libclang==18.1.1
# librosa==0.10.1
# lightgbm==4.1.0
# linkify-it-py==2.0.3
# llvmlite==0.41.1
# locket==1.0.0
# logical-unification==0.4.6
# lxml==4.9.4
# malloy==2023.1067
# Markdown==3.6
# markdown-it-py==3.0.0
# MarkupSafe==2.1.5
# matplotlib==3.7.1
# matplotlib-inline==0.1.6
# matplotlib-venn==0.11.10
# mdit-py-plugins==0.4.0
# mdurl==0.1.2
# miniKanren==1.0.3
# missingno==0.5.2
# mistune==0.8.4
# mizani==0.9.3
# mkl==2023.2.0
# ml-dtypes==0.2.0
# mlxtend==0.22.0
# more-itertools==10.1.0
# moviepy==1.0.3
# mpmath==1.3.0
# msgpack==1.0.8
# multidict==6.0.5
# multipledispatch==1.0.0
# multiprocess==0.70.16
# multitasking==0.0.11
# murmurhash==1.0.10
# music21==9.1.0
# natsort==8.4.0
# nbclassic==1.0.0
# nbclient==0.10.0
# nbconvert==6.5.4
# nbformat==5.10.3
# nest-asyncio==1.6.0
# networkx==3.2.1
# nibabel==4.0.2
# ninja==1.11.1.1
# nltk==3.8.1
# nodeenv==1.8.0
# notebook==6.5.5
# notebook_shim==0.2.4
# numba==0.58.1
# numexpr==2.10.0
# numpy==1.25.2
# nvidia-cublas-cu12==12.1.3.1
# nvidia-cuda-cupti-cu12==12.1.105
# nvidia-cuda-nvrtc-cu12==12.1.105
# nvidia-cuda-runtime-cu12==12.1.105
# nvidia-cudnn-cu12==8.9.2.26
# nvidia-cufft-cu12==11.0.2.54
# nvidia-curand-cu12==10.3.2.106
# nvidia-cusolver-cu12==11.4.5.107
# nvidia-cusparse-cu12==12.1.0.106
# nvidia-nccl-cu12==2.19.3
# nvidia-nvjitlink-cu12==12.4.127
# nvidia-nvtx-cu12==12.1.105
# oauth2client==4.1.3
# oauthlib==3.2.2
# opencv-contrib-python==4.8.0.76
# opencv-python==4.8.0.76
# opencv-python-headless==4.9.0.80
# openpyxl==3.1.2
# opt-einsum==3.3.0
# optax==0.2.2
# orbax-checkpoint==0.4.4
# osqp==0.6.2.post8
# packaging==24.0
# pandas==2.0.3
# pandas-datareader==0.10.0
# pandas-gbq==0.19.2
# pandas-stubs==2.0.3.230814
# pandocfilters==1.5.1
# panel==1.3.8
# param==2.1.0
# paramiko==3.4.0
# parso==0.8.3
# parsy==2.1
# partd==1.4.1
# pathlib==1.0.1
# patsy==0.5.6
# peewee==3.17.1
# pexpect==4.9.0
# pickleshare==0.7.5
# Pillow==9.4.0
# pip-tools==6.13.0
# platformdirs==4.2.0
# plotly==5.15.0
# plotnine==0.12.4
# pluggy==1.4.0
# polars==0.20.2
# pooch==1.8.1
# portpicker==1.5.2
# pre-commit==3.7.0
# prefetch-generator==1.0.3
# preshed==3.0.9
# prettytable==3.10.0
# proglog==0.1.10
# progressbar2==4.2.0
# prometheus_client==0.20.0
# promise==2.3
# prompt-toolkit==3.0.43
# prophet==1.1.5
# proto-plus==1.23.0
# protobuf==3.20.3
# psutil==5.9.5
# psycopg2==2.9.9
# ptyprocess==0.7.0
# py-cpuinfo==9.0.0
# py4j==0.10.9.7
# pyarrow==14.0.2
# pyarrow-hotfix==0.6
# pyasn1==0.6.0
# pyasn1_modules==0.4.0
# pycocotools==2.0.7
# pycparser==2.22
# pydantic==2.6.4
# pydantic_core==2.16.3
# pydata-google-auth==1.8.2
# pydot==1.4.2
# pydot-ng==2.0.0
# pydotplus==2.0.2
# PyDrive==1.3.1
# PyDrive2==1.6.3
# pyerfa==2.0.1.1
# pygame==2.5.2
# Pygments==2.16.1
# PyGObject==3.42.1
# PyJWT==2.3.0
# pymc==5.10.4
# pymystem3==0.2.0
# PyNaCl==1.5.0
# PyOpenGL==3.1.7
# pyOpenSSL==24.1.0
# pyparsing==3.1.2
# pyperclip==1.8.2
# pyproj==3.6.1
# pyproject_hooks==1.0.0
# pyshp==2.3.1
# PySocks==1.7.1
# pytensor==2.18.6
# pytest==7.4.4
# python-apt @ file:///backend-container/containers/python_apt-0.0.0-cp310-cp310-linux_x86_64.whl#sha256=b209c7165d6061963abe611492f8c91c3bcef4b7a6600f966bab58900c63fefa
# python-box==7.1.1
# python-dateutil==2.8.2
# python-louvain==0.16
# python-slugify==8.0.4
# python-utils==3.8.2
# pytz==2023.4
# pyviz_comms==3.0.2
# PyWavelets==1.6.0
# PyYAML==6.0.1
# pyzmq==23.2.1
# qdldl==0.1.7.post0
# qudida==0.0.4
# ratelim==0.1.6
# ray==2.10.0
# referencing==0.34.0
# regex==2023.12.25
# requests==2.31.0
# requests-oauthlib==1.3.1
# requirements-parser==0.9.0
# rich==13.7.1
# rpds-py==0.18.0
# rpy2==3.4.2
# rsa==4.9
# safetensors==0.4.2
# scikit-image==0.19.3
# scikit-learn==1.2.2
# scipy==1.11.4
# scooby==0.9.2
# scs==3.2.4.post1
# seaborn==0.13.1
# SecretStorage==3.3.1
# Send2Trash==1.8.2
# sentencepiece==0.1.99
# shapely==2.0.3
# six==1.16.0
# sklearn-pandas==2.2.0
# smart-open==6.4.0
# sniffio==1.3.1
# snowballstemmer==2.2.0
# sortedcontainers==2.4.0
# soundfile==0.12.1
# soupsieve==2.5
# soxr==0.3.7
# spacy==3.7.4
# spacy-legacy==3.0.12
# spacy-loggers==1.0.5
# Sphinx==5.0.2
# sphinxcontrib-applehelp==1.0.8
# sphinxcontrib-devhelp==1.0.6
# sphinxcontrib-htmlhelp==2.0.5
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.7
# sphinxcontrib-serializinghtml==1.1.10
# SQLAlchemy==2.0.29
# sqlglot==20.11.0
# sqlparse==0.4.4
# srsly==2.4.8
# stanio==0.5.0
# statsmodels==0.14.1
# sympy==1.12
# tables==3.8.0
# tabulate==0.9.0
# tbb==2021.12.0
# tblib==3.0.0
# tenacity==8.2.3
# tensorboard==2.15.2
# tensorboard-data-server==0.7.2
# tensorflow @ https://storage.googleapis.com/colab-tf-builds-public-09h6ksrfwbb9g9xv/tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl#sha256=a2ec79931350b378c1ef300ca836b52a55751acb71a433582508a07f0de57c42
# tensorflow-datasets==4.9.4
# tensorflow-estimator==2.15.0
# tensorflow-gcs-config==2.15.0
# tensorflow-hub==0.16.1
# tensorflow-io-gcs-filesystem==0.36.0
# tensorflow-metadata==1.14.0
# tensorflow-probability==0.23.0
# tensorstore==0.1.45
# termcolor==2.4.0
# terminado==0.18.1
# text-unidecode==1.3
# textblob==0.17.1
# tf-slim==1.1.0
# tf_keras==2.15.1
# thinc==8.2.3
# threadpoolctl==3.4.0
# tifffile==2024.2.12
# tinycss2==1.2.1
# tokenizers==0.15.2
# toml==0.10.2
# tomli==2.0.1
# toolz==0.12.1
# torch @ https://download.pytorch.org/whl/cu121/torch-2.2.1%2Bcu121-cp310-cp310-linux_x86_64.whl#sha256=1adf430f01ff649c848ac021785e18007b0714fdde68e4e65bd0c640bf3fb8e1
# torchaudio @ https://download.pytorch.org/whl/cu121/torchaudio-2.2.1%2Bcu121-cp310-cp310-linux_x86_64.whl#sha256=23f6236429e2bf676b820e8e7221a1d58aaf908bff2ba2665aa852df71a97961
# torchdata==0.7.1
# torchsummary==1.5.1
# torchtext==0.17.1
# torchvision @ https://download.pytorch.org/whl/cu121/torchvision-0.17.1%2Bcu121-cp310-cp310-linux_x86_64.whl#sha256=27af47915f6e762c1d44e58e8088d22ac97445668f9f793524032b2baf4f34bd
# tornado==6.3.3
# tqdm==4.66.2
# traitlets==5.7.1
# traittypes==0.2.1
# transformers==4.38.2
# triton==2.2.0
# tweepy==4.14.0
# typer==0.9.4
# types-pytz==2024.1.0.20240203
# types-setuptools==69.2.0.20240317
# typing_extensions==4.10.0
# tzdata==2024.1
# tzlocal==5.2
# uc-micro-py==1.0.3
# uritemplate==4.1.1
# urllib3==2.0.7
# vega-datasets==0.9.0
# virtualenv==20.25.1
# wadllib==1.3.6
# wasabi==1.1.2
# wcwidth==0.2.13
# weasel==0.3.4
# webcolors==1.13
# webencodings==0.5.1
# websocket-client==1.7.0
# Werkzeug==3.0.2
# widgetsnbextension==3.6.6
# wordcloud==1.9.3
# wrapt==1.14.1
# xarray==2023.7.0
# xarray-einstats==0.7.0
# xgboost==2.0.3
# xlrd==2.0.1
# xxhash==3.4.1
# xyzservices==2024.4.0
# yarl==1.9.4
# yellowbrick==1.5
# yfinance==0.2.37
# zict==3.0.0
# zipp==3.18.1

# %%
import torch

# %%
torch.__version__
# Out:
# '2.2.1+cu121'

# %%
# %cd drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt
# !ls
# Out:
# /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt
# benchmark.sh	    epoch_444_model.pth  README.md	   run_clm.py		 test_ci.sh
# colossalai_zero.py  logs		 requirements.txt  run_clm.sh
# context.py	    __pycache__		 run_clm2.sh	   run_clm_synthetic.sh

# %%
# !bash run_clm.sh
# Out:
# + export BS=16
# + BS=16
# + export MEMCAP=0
# + MEMCAP=0
# + export MODEL=125m
# + MODEL=125m
# + export GPUNUM=1
# + GPUNUM=1
# + mkdir -p ./logs
# + export MODLE_PATH=facebook/opt-125m
# + MODLE_PATH=facebook/opt-125m
# + tee ./logs/colo_125m_bs_16_cap_0_gpu_1.log
# + torchrun --nproc_per_node 1 --master_port 19198 run_clm.py --dataset_name wikitext --dataset_config_name wikitext-2-raw-v1 --output_dir /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt --mem_cap 0 --model_name_or_path facebook/opt-125m --per_device_train_batch_size 16
# 2024-04-09 10:59:53.188766: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-09 10:59:53.188817: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-09 10:59:53.322338: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-09 10:59:55.198600: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [04/09/24 10:59:56] INFO     colossalai - colossalai - INFO:
#                              /usr/local/lib/python3.10/dist-packages/colossalai/legacy/context/paral
#                              lel_context.py:536 set_device
#                     INFO     colossalai - colossalai - INFO: process rank 0 is bound to device 0
# [04/09/24 10:59:57] INFO     colossalai - colossalai - INFO:
#                              /usr/local/lib/python3.10/dist-packages/colossalai/legacy/context/paral
#                              lel_context.py:572 set_seed
#                     INFO     colossalai - colossalai - INFO: initialized seed on rank 0, numpy:
#                              1024, python random: 1024, ParallelMode.DATA: 1024,
#                              ParallelMode.TENSOR: 1024,the default parallel seed is
#                              ParallelMode.DATA.
#                     INFO     colossalai - colossalai - INFO:
#                              /usr/local/lib/python3.10/dist-packages/colossalai/legacy/initialize.py
#                              :118 launch
#                     INFO     colossalai - colossalai - INFO: Distributed environment is initialized,
#                              data parallel size: 1, pipeline parallel size: 1, tensor parallel size:
#                              1
#                     INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:325 main
#                     INFO     colossalai - colossalai - INFO: Start preparing dataset
# Downloading readme: 100%|██████████| 10.5k/10.5k [00:00<00:00, 24.4MB/s]
# Downloading data: 100%|██████████| 733k/733k [00:00<00:00, 3.15MB/s]
# Downloading data: 100%|██████████| 6.36M/6.36M [00:00<00:00, 34.0MB/s]
# Downloading data: 100%|██████████| 657k/657k [00:00<00:00, 6.01MB/s]
# Generating test split: 100%|██████████| 4358/4358 [00:00<00:00, 117942.81 examples/s]
# Generating train split: 100%|██████████| 36718/36718 [00:00<00:00, 744308.95 examples/s]
# Generating validation split: 100%|██████████| 3760/3760 [00:00<00:00, 422034.44 examples/s]
# [04/09/24 11:00:01] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:367 main
#                     INFO     colossalai - colossalai - INFO: Dataset is prepared
# config.json: 100%|██████████| 651/651 [00:00<00:00, 3.19MB/s]
#                     INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:383 main
#                     INFO     colossalai - colossalai - INFO: Model config has been created
# load model from facebook/opt-125m
# tokenizer_config.json: 100%|██████████| 685/685 [00:00<00:00, 3.49MB/s]
# vocab.json: 100%|██████████| 899k/899k [00:00<00:00, 2.71MB/s]
# merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 1.84MB/s]
# special_tokens_map.json: 100%|██████████| 441/441 [00:00<00:00, 2.20MB/s]
# [04/09/24 11:00:03] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:390 main
#                     INFO     colossalai - colossalai - INFO: GPT2TokenizerFast has been created
#                     INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:398 main
#                     INFO     colossalai - colossalai - INFO: using Colossal-AI version 0.3.6
#                     INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:421 main
#                     INFO     colossalai - colossalai - INFO: Finetune a pre-trained model
# pytorch_model.bin: 100%|██████████| 251M/251M [00:01<00:00, 245MB/s]
# generation_config.json: 100%|██████████| 137/137 [00:00<00:00, 583kB/s]
# /usr/local/lib/python3.10/dist-packages/colossalai/zero/gemini/chunk/chunk.py:45: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return tensor.storage().size() == 0
# [04/09/24 11:00:08] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:461 main
#                     INFO     colossalai - colossalai - INFO: GeminiDDP has been created
# Running tokenizer on dataset: 100%|██████████| 4358/4358 [00:01<00:00, 4302.02 examples/s]
# Running tokenizer on dataset: 100%|██████████| 36718/36718 [00:06<00:00, 5682.22 examples/s]
# Running tokenizer on dataset: 100%|██████████| 3760/3760 [00:01<00:00, 3335.83 examples/s]
# [04/09/24 11:00:17] WARNING  colossalai - colossalai - WARNING:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:485 main
#                     WARNING  colossalai - colossalai - WARNING: The tokenizer picked seems to have a
#                              very large `model_max_length` (1000000000000000019884624838656).
#                              Picking 1024 instead. You can change that default value by passing
#                              --block_size xxx.
# Grouping texts in chunks of 1024: 100%|██████████| 4358/4358 [00:00<00:00, 6796.68 examples/s]
# Grouping texts in chunks of 1024: 100%|██████████| 36718/36718 [00:03<00:00, 10002.04 examples/s]
# Grouping texts in chunks of 1024: 100%|██████████| 3760/3760 [00:00<00:00, 11954.74 examples/s]
# [04/09/24 11:00:21] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:557 main
#                     INFO     colossalai - colossalai - INFO: Dataloaders have been created
# /usr/local/lib/python3.10/dist-packages/colossalai/kernel/extensions/utils.py:96: UserWarning: [extension] The CUDA version on the system (12.2) does not match with the version (12.1) torch was compiled with. The mismatch is found in the minor version. As the APIs are compatible, we will allow compilation to proceed. If you encounter any issue when using the built kernel, please try to build it again with fully matched CUDA versions
#   warnings.warn(
# [extension] Compiling the JIT cpu_adam_x86 kernel during runtime now
# [extension] Time taken to compile cpu_adam_x86 op: 37.44317841529846 seconds
# /usr/local/lib/python3.10/dist-packages/colossalai/kernel/extensions/utils.py:96: UserWarning: [extension] The CUDA version on the system (12.2) does not match with the version (12.1) torch was compiled with. The mismatch is found in the minor version. As the APIs are compatible, we will allow compilation to proceed. If you encounter any issue when using the built kernel, please try to build it again with fully matched CUDA versions
#   warnings.warn(
# [extension] Compiling the JIT fused_optim_cuda kernel during runtime now
# [extension] Time taken to compile fused_optim_cuda op: 233.45999026298523 seconds
# /usr/local/lib/python3.10/dist-packages/colossalai/nn/optimizer/hybrid_adam.py:90: UserWarning: The torch.cuda.*DtypeTensor constructors are no longer recommended. It's best to use methods such as torch.tensor(data, dtype=*, device='cuda') to create tensors. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:83.)
#   self._dummy_overflow_buf = torch.cuda.IntTensor([0])
# [04/09/24 11:04:53] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:602 main
#                     INFO     colossalai - colossalai - INFO: ***** Running training *****
#                     INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:603 main
#                     INFO     colossalai - colossalai - INFO:   Num examples = 2355
#                     INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:604 main
#                     INFO     colossalai - colossalai - INFO:   Num Epochs = 3
#                     INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:605 main
#                     INFO     colossalai - colossalai - INFO:   Instantaneous batch size per device =
#                              16
#                     INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:606 main
#                     INFO     colossalai - colossalai - INFO:   Total train batch size (w. parallel,
#                              distributed & accumulation) = 16
#                     INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:607 main
#                     INFO     colossalai - colossalai - INFO:   Gradient Accumulation steps = 1
#                     INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:608 main
#                     INFO     colossalai - colossalai - INFO:   Total optimization steps = 444
#   0%|          | 1/444 [00:04<31:57,  4.33s/it][04/09/24 11:04:57] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 2 finished
#   0%|          | 2/444 [00:06<23:37,  3.21s/it][04/09/24 11:05:00] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 3 finished
#   1%|          | 3/444 [00:09<20:57,  2.85s/it][04/09/24 11:05:02] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 4 finished
#   1%|          | 4/444 [00:11<19:41,  2.69s/it][04/09/24 11:05:04] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 5 finished
#   1%|          | 5/444 [00:14<18:58,  2.59s/it][04/09/24 11:05:07] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 6 finished
#   1%|▏         | 6/444 [00:16<18:40,  2.56s/it][04/09/24 11:05:09] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 7 finished
#   2%|▏         | 7/444 [00:19<18:26,  2.53s/it][04/09/24 11:05:12] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 8 finished
#   2%|▏         | 8/444 [00:21<18:16,  2.51s/it][04/09/24 11:05:14] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 9 finished
#   2%|▏         | 9/444 [00:23<18:06,  2.50s/it][04/09/24 11:05:17] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 10 finished
#   2%|▏         | 10/444 [00:26<17:58,  2.49s/it][04/09/24 11:05:19] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 11 finished
#   2%|▏         | 11/444 [00:28<17:58,  2.49s/it][04/09/24 11:05:22] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 12 finished
#   3%|▎         | 12/444 [00:31<17:51,  2.48s/it][04/09/24 11:05:24] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 13 finished
#   3%|▎         | 13/444 [00:33<17:49,  2.48s/it][04/09/24 11:05:27] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 14 finished
#   3%|▎         | 14/444 [00:36<17:47,  2.48s/it][04/09/24 11:05:29] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 15 finished
#   3%|▎         | 15/444 [00:38<17:46,  2.49s/it][04/09/24 11:05:32] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 16 finished
#   4%|▎         | 16/444 [00:41<17:52,  2.51s/it][04/09/24 11:05:34] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 17 finished
#   4%|▍         | 17/444 [00:43<17:52,  2.51s/it][04/09/24 11:05:37] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 18 finished
#   4%|▍         | 18/444 [00:46<17:42,  2.49s/it][04/09/24 11:05:39] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 19 finished
#   4%|▍         | 19/444 [00:48<17:43,  2.50s/it][04/09/24 11:05:42] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 20 finished
#   5%|▍         | 20/444 [00:51<17:42,  2.51s/it][04/09/24 11:05:44] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 21 finished
#   5%|▍         | 21/444 [00:53<17:47,  2.52s/it][04/09/24 11:05:47] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 22 finished
#   5%|▍         | 22/444 [00:56<17:51,  2.54s/it][04/09/24 11:05:49] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 23 finished
#   5%|▌         | 23/444 [00:59<17:53,  2.55s/it][04/09/24 11:05:52] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 24 finished
#   5%|▌         | 24/444 [01:01<17:52,  2.55s/it][04/09/24 11:05:55] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 25 finished
#   6%|▌         | 25/444 [01:04<17:51,  2.56s/it][04/09/24 11:05:57] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 26 finished
#   6%|▌         | 26/444 [01:06<17:55,  2.57s/it][04/09/24 11:06:00] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 27 finished
#   6%|▌         | 27/444 [01:09<17:53,  2.57s/it][04/09/24 11:06:02] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 28 finished
#   6%|▋         | 28/444 [01:11<17:47,  2.57s/it][04/09/24 11:06:05] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 29 finished
#   7%|▋         | 29/444 [01:14<17:42,  2.56s/it][04/09/24 11:06:07] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 30 finished
#   7%|▋         | 30/444 [01:17<17:36,  2.55s/it][04/09/24 11:06:10] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 31 finished
#   7%|▋         | 31/444 [01:19<17:36,  2.56s/it][04/09/24 11:06:12] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
# [04/09/24 11:06:13] INFO     colossalai - colossalai - INFO: Global step 32 finished
#   7%|▋         | 32/444 [01:22<17:38,  2.57s/it][04/09/24 11:06:15] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 33 finished
#   7%|▋         | 33/444 [01:24<17:32,  2.56s/it][04/09/24 11:06:18] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 34 finished
#   8%|▊         | 34/444 [01:27<17:22,  2.54s/it][04/09/24 11:06:20] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 35 finished
#   8%|▊         | 35/444 [01:29<17:16,  2.53s/it][04/09/24 11:06:23] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 36 finished
#   8%|▊         | 36/444 [01:32<17:08,  2.52s/it][04/09/24 11:06:25] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 37 finished
#   8%|▊         | 37/444 [01:34<17:10,  2.53s/it][04/09/24 11:06:28] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 38 finished
#   9%|▊         | 38/444 [01:37<17:07,  2.53s/it][04/09/24 11:06:30] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 39 finished
#   9%|▉         | 39/444 [01:39<17:01,  2.52s/it][04/09/24 11:06:33] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 40 finished
#   9%|▉         | 40/444 [01:42<16:55,  2.51s/it][04/09/24 11:06:35] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 41 finished
#   9%|▉         | 41/444 [01:44<16:51,  2.51s/it][04/09/24 11:06:38] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 42 finished
#   9%|▉         | 42/444 [01:47<16:52,  2.52s/it][04/09/24 11:06:40] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 43 finished
#  10%|▉         | 43/444 [01:49<16:50,  2.52s/it][04/09/24 11:06:43] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 44 finished
#  10%|▉         | 44/444 [01:52<16:44,  2.51s/it][04/09/24 11:06:45] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 45 finished
#  10%|█         | 45/444 [01:54<16:39,  2.51s/it][04/09/24 11:06:48] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 46 finished
#  10%|█         | 46/444 [01:57<16:36,  2.50s/it][04/09/24 11:06:50] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 47 finished
#  11%|█         | 47/444 [01:59<16:38,  2.52s/it][04/09/24 11:06:53] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 48 finished
#  11%|█         | 48/444 [02:02<16:39,  2.52s/it][04/09/24 11:06:55] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 49 finished
#  11%|█         | 49/444 [02:04<16:34,  2.52s/it][04/09/24 11:06:58] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 50 finished
#  11%|█▏        | 50/444 [02:07<16:33,  2.52s/it][04/09/24 11:07:00] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 51 finished
#  11%|█▏        | 51/444 [02:10<16:30,  2.52s/it][04/09/24 11:07:03] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 52 finished
#  12%|█▏        | 52/444 [02:12<16:31,  2.53s/it][04/09/24 11:07:05] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 53 finished
#  12%|█▏        | 53/444 [02:15<16:31,  2.54s/it][04/09/24 11:07:08] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 54 finished
#  12%|█▏        | 54/444 [02:17<16:27,  2.53s/it][04/09/24 11:07:11] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 55 finished
#  12%|█▏        | 55/444 [02:20<16:25,  2.53s/it][04/09/24 11:07:13] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 56 finished
#  13%|█▎        | 56/444 [02:22<16:22,  2.53s/it][04/09/24 11:07:16] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 57 finished
#  13%|█▎        | 57/444 [02:25<16:22,  2.54s/it][04/09/24 11:07:18] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 58 finished
#  13%|█▎        | 58/444 [02:27<16:20,  2.54s/it][04/09/24 11:07:21] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 59 finished
#  13%|█▎        | 59/444 [02:30<16:17,  2.54s/it][04/09/24 11:07:23] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 60 finished
#  14%|█▎        | 60/444 [02:32<16:13,  2.54s/it][04/09/24 11:07:26] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 61 finished
#  14%|█▎        | 61/444 [02:35<16:11,  2.54s/it][04/09/24 11:07:28] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 62 finished
#  14%|█▍        | 62/444 [02:37<16:12,  2.55s/it][04/09/24 11:07:31] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 63 finished
#  14%|█▍        | 63/444 [02:40<16:10,  2.55s/it][04/09/24 11:07:33] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 64 finished
#  14%|█▍        | 64/444 [02:43<16:04,  2.54s/it][04/09/24 11:07:36] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 65 finished
#  15%|█▍        | 65/444 [02:45<15:59,  2.53s/it][04/09/24 11:07:38] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 66 finished
#  15%|█▍        | 66/444 [02:48<15:55,  2.53s/it][04/09/24 11:07:41] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 67 finished
#  15%|█▌        | 67/444 [02:50<15:56,  2.54s/it][04/09/24 11:07:44] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 68 finished
#  15%|█▌        | 68/444 [02:53<16:01,  2.56s/it][04/09/24 11:07:46] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 69 finished
#  16%|█▌        | 69/444 [02:55<15:53,  2.54s/it][04/09/24 11:07:49] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 70 finished
#  16%|█▌        | 70/444 [02:58<15:46,  2.53s/it][04/09/24 11:07:51] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 71 finished
#  16%|█▌        | 71/444 [03:00<15:42,  2.53s/it][04/09/24 11:07:54] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 72 finished
#  16%|█▌        | 72/444 [03:03<15:39,  2.52s/it][04/09/24 11:07:56] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 73 finished
#  16%|█▋        | 73/444 [03:05<15:42,  2.54s/it][04/09/24 11:07:59] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 74 finished
#  17%|█▋        | 74/444 [03:08<15:39,  2.54s/it][04/09/24 11:08:01] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 75 finished
#  17%|█▋        | 75/444 [03:10<15:34,  2.53s/it][04/09/24 11:08:04] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 76 finished
#  17%|█▋        | 76/444 [03:13<15:29,  2.53s/it][04/09/24 11:08:06] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 77 finished
# ...
#  93%|█████████▎| 412/444 [17:42<01:21,  2.54s/it][04/09/24 11:22:36] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 413 finished
#  93%|█████████▎| 413/444 [17:45<01:18,  2.54s/it][04/09/24 11:22:38] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 414 finished
#  93%|█████████▎| 414/444 [17:47<01:16,  2.55s/it][04/09/24 11:22:41] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 415 finished
#  93%|█████████▎| 415/444 [17:50<01:13,  2.54s/it][04/09/24 11:22:43] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 416 finished
#  94%|█████████▎| 416/444 [17:53<01:11,  2.54s/it][04/09/24 11:22:46] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 417 finished
#  94%|█████████▍| 417/444 [17:55<01:08,  2.53s/it][04/09/24 11:22:48] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 418 finished
#  94%|█████████▍| 418/444 [17:58<01:06,  2.54s/it][04/09/24 11:22:51] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 419 finished
#  94%|█████████▍| 419/444 [18:00<01:03,  2.55s/it][04/09/24 11:22:54] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 420 finished
#  95%|█████████▍| 420/444 [18:03<01:00,  2.54s/it][04/09/24 11:22:56] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 421 finished
#  95%|█████████▍| 421/444 [18:05<00:58,  2.54s/it][04/09/24 11:22:59] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 422 finished
#  95%|█████████▌| 422/444 [18:08<00:55,  2.53s/it][04/09/24 11:23:01] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 423 finished
#  95%|█████████▌| 423/444 [18:10<00:53,  2.55s/it][04/09/24 11:23:04] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 424 finished
#  95%|█████████▌| 424/444 [18:13<00:50,  2.54s/it][04/09/24 11:23:06] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 425 finished
#  96%|█████████▌| 425/444 [18:15<00:48,  2.53s/it][04/09/24 11:23:09] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 426 finished
#  96%|█████████▌| 426/444 [18:18<00:45,  2.53s/it][04/09/24 11:23:11] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 427 finished
#  96%|█████████▌| 427/444 [18:20<00:42,  2.52s/it][04/09/24 11:23:14] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 428 finished
#  96%|█████████▋| 428/444 [18:23<00:40,  2.53s/it][04/09/24 11:23:16] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 429 finished
#  97%|█████████▋| 429/444 [18:26<00:38,  2.54s/it][04/09/24 11:23:19] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 430 finished
#  97%|█████████▋| 430/444 [18:28<00:35,  2.54s/it][04/09/24 11:23:21] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 431 finished
#  97%|█████████▋| 431/444 [18:31<00:32,  2.53s/it][04/09/24 11:23:24] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 432 finished
#  97%|█████████▋| 432/444 [18:33<00:30,  2.53s/it][04/09/24 11:23:26] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 433 finished
#  98%|█████████▊| 433/444 [18:36<00:27,  2.54s/it][04/09/24 11:23:29] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 434 finished
#  98%|█████████▊| 434/444 [18:38<00:25,  2.55s/it][04/09/24 11:23:32] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 435 finished
#  98%|█████████▊| 435/444 [18:41<00:22,  2.55s/it][04/09/24 11:23:34] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 436 finished
#  98%|█████████▊| 436/444 [18:43<00:20,  2.54s/it][04/09/24 11:23:37] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 437 finished
#  98%|█████████▊| 437/444 [18:46<00:17,  2.53s/it][04/09/24 11:23:39] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 438 finished
#  99%|█████████▊| 438/444 [18:48<00:15,  2.53s/it][04/09/24 11:23:42] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 439 finished
#  99%|█████████▉| 439/444 [18:51<00:12,  2.55s/it][04/09/24 11:23:44] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 440 finished
#  99%|█████████▉| 440/444 [18:53<00:10,  2.55s/it][04/09/24 11:23:47] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 441 finished
#  99%|█████████▉| 441/444 [18:56<00:07,  2.54s/it][04/09/24 11:23:49] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 442 finished
# 100%|█████████▉| 442/444 [18:59<00:05,  2.54s/it][04/09/24 11:23:52] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 443 finished
# 100%|█████████▉| 443/444 [19:01<00:02,  2.54s/it][04/09/24 11:23:54] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 444 finished
# 100%|██████████| 444/444 [19:02<00:00,  2.00s/it][04/09/24 11:23:55] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:635 main
#                     INFO     colossalai - colossalai - INFO: Global step 445 finished
# [04/09/24 11:24:05] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:658 main
#                     INFO     colossalai - colossalai - INFO: Epoch 2: perplexity: 19.505629671380603
#                              eval_loss: ColoTensor(2.9707, device='cuda:0', dtype=torch.float16)
# [04/09/24 11:24:08] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:668 main
#                     INFO     colossalai - colossalai - INFO: Training finished
# 100%|██████████| 444/444 [19:14<00:00,  2.60s/it]

# %%
# !pwd
# Out:
# /content

# %%
# !pip freeze > requirements.txt

# %%
# !bash run_clm_350m.sh
# Out:
# + export BS=16
# + BS=16
# + export MEMCAP=0
# + MEMCAP=0
# + export MODEL=350m
# + MODEL=350m
# + export GPUNUM=1
# + GPUNUM=1
# + mkdir -p ./logs
# + export MODLE_PATH=facebook/opt-350m
# + MODLE_PATH=facebook/opt-350m
# + torchrun --nproc_per_node 1 --master_port 19198 run_clm.py --dataset_name wikitext --dataset_config_name wikitext-2-raw-v1 --output_dir /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt --mem_cap 0 --model_name_or_path facebook/opt-350m --per_device_train_batch_size 16
# + tee ./logs/colo_350m_bs_16_cap_0_gpu_1.log
# 2024-04-09 12:04:27.748275: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-09 12:04:27.748322: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-09 12:04:27.749872: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-09 12:04:29.034121: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [04/09/24 12:04:29] INFO     colossalai - colossalai - INFO:
#                              /usr/local/lib/python3.10/dist-packages/colossalai/legacy/context/paral
#                              lel_context.py:536 set_device
#                     INFO     colossalai - colossalai - INFO: process rank 0 is bound to device 0
# [04/09/24 12:04:30] INFO     colossalai - colossalai - INFO:
#                              /usr/local/lib/python3.10/dist-packages/colossalai/legacy/context/paral
#                              lel_context.py:572 set_seed
#                     INFO     colossalai - colossalai - INFO: initialized seed on rank 0, numpy:
#                              1024, python random: 1024, ParallelMode.DATA: 1024,
#                              ParallelMode.TENSOR: 1024,the default parallel seed is
#                              ParallelMode.DATA.
#                     INFO     colossalai - colossalai - INFO:
#                              /usr/local/lib/python3.10/dist-packages/colossalai/legacy/initialize.py
#                              :118 launch
#                     INFO     colossalai - colossalai - INFO: Distributed environment is initialized,
#                              data parallel size: 1, pipeline parallel size: 1, tensor parallel size:
#                              1
#                     INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:325 main
#                     INFO     colossalai - colossalai - INFO: Start preparing dataset
# [04/09/24 12:04:32] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:367 main
#                     INFO     colossalai - colossalai - INFO: Dataset is prepared
#                     INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:383 main
#                     INFO     colossalai - colossalai - INFO: Model config has been created
# load model from facebook/opt-350m
# [04/09/24 12:04:33] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:390 main
#                     INFO     colossalai - colossalai - INFO: GPT2TokenizerFast has been created
#                     INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:398 main
#                     INFO     colossalai - colossalai - INFO: using Colossal-AI version 0.3.6
#                     INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:421 main
#                     INFO     colossalai - colossalai - INFO: Finetune a pre-trained model
# /usr/local/lib/python3.10/dist-packages/colossalai/zero/gemini/chunk/chunk.py:45: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return tensor.storage().size() == 0
# [04/09/24 12:04:41] INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:461 main
#                     INFO     colossalai - colossalai - INFO: GeminiDDP has been created
#                     WARNING  colossalai - colossalai - WARNING:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:485 main
#                     WARNING  colossalai - colossalai - WARNING: The tokenizer picked seems to have a
#                              very large `model_max_length` (1000000000000000019884624838656).
#                              Picking 1024 instead. You can change that default value by passing
#                              --block_size xxx.
#                     INFO     colossalai - colossalai - INFO:
#                              /content/drive/MyDrive/ass6/ColossalAI/examples/tutorial/opt/opt/run_cl
#                              m.py:557 main
#                     INFO     colossalai - colossalai - INFO: Dataloaders have been created
# /usr/local/lib/python3.10/dist-packages/colossalai/kernel/extensions/utils.py:96: UserWarning: [extension] The CUDA version on the system (12.2) does not match with the version (12.1) torch was compiled with. The mismatch is found in the minor version. As the APIs are compatible, we will allow compilation to proceed. If you encounter any issue when using the built kernel, please try to build it again with fully matched CUDA versions
#   warnings.warn(
# [extension] Compiling the JIT cpu_adam_x86 kernel during runtime now
